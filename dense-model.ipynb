# %% [markdown]
# ### Import Libraries

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout, LSTM
from sklearn.metrics import mean_absolute_error
from datetime import datetime

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ### Import data

# %%
crypto_df = pd.read_csv("../input/g-research-crypto-forecasting/train.csv")

# %%
crypto_df.head()
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2   40.0   2376.5800   2399.5000   2357.1400
# 1  1514764860         0    5.0      8.5300      8.5300      8.5300
# 2  1514764860         1  229.0  13835.1940  14013.8000  13666.1100
# 3  1514764860         5   32.0      7.6596      7.6596      7.6567
# 4  1514764860         7    5.0     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264

# %%
asset_details = pd.read_csv('../input/g-research-crypto-forecasting/asset_details.csv')
asset_details
# Out:
#     Asset_ID    Weight        Asset_Name
# 0          2  2.397895      Bitcoin Cash
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 3          5  1.386294            EOS.IO
# 4          7  2.079442  Ethereum Classic
# 5          6  5.894403          Ethereum
# 6          9  2.397895          Litecoin
# 7         11  1.609438            Monero
# 8         13  1.791759              TRON
# 9         12  2.079442           Stellar
# 10         3  4.406719           Cardano
# 11         8  1.098612              IOTA
# 12        10  1.098612             Maker
# 13         4  3.555348          Dogecoin

# %%
# Select Asset_ID = 6 for Ethereum
crypto_df = crypto_df[crypto_df["Asset_ID"]==6] 
crypto_df.info(show_counts =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1956200 entries, 5 to 24236799
# Data columns (total 10 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   timestamp  1956200 non-null  int64
#  1   Asset_ID   1956200 non-null  int64
#  2   Count      1956200 non-null  float64
#  3   Open       1956200 non-null  float64
#  4   High       1956200 non-null  float64
#  5   Low        1956200 non-null  float64
#  6   Close      1956200 non-null  float64
#  7   Volume     1956200 non-null  float64
#  8   VWAP       1956200 non-null  float64
#  9   Target     1955860 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 164.2 MB

# %% [markdown]
# ###  Preprocessing

# %%
df = crypto_df.copy()

# %%
# fill missing values 
df = df.reindex(range(df.index[0],df.index[-1]+60,60),method='pad')
df = df.fillna(0)

# %%
# rename column timestamp to Date
df.rename({'timestamp': 'Date'}, axis=1, inplace=True)
df.rename(columns={'Close': 'Price'}, inplace=True)

# %%
# set index
df.set_index('Date', inplace=True)

# %%
# Convert to date array
timesteps = df.index.to_numpy()
prices = df['Price'].to_numpy()

timesteps[:10], prices[:10]
# Out:
# (array([1514764860, 1514765280, 1514765760, 1514766240, 1514766660,
#         1514767140, 1514767620, 1514768100, 1514768580, 1514769060]),
#  array([738.5075, 735.09  , 734.8025, 731.82  , 732.9325, 732.3425,
#         731.8225, 732.1325, 732.605 , 729.415 ]))

# %% [markdown]
# ### Modeling Dense model

# %%
# Create Window dataset
HORIZON = 1      # predict 1 step at a time
WINDOW_SIZE = 7  # use a week worth of timesteps to predict the horizon

# %%
# Create function to label windowed data
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.
  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# Test the window labelling function
test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")
# Out:
# Window: [1 2 3 4 5 6 7] -> Label: 8

# %%
# Create function to view NumPy arrays as windows
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T 
  windowed_array = x[window_indexes]
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
full_windows, full_labels = make_windows(prices, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (403941, 403941)

# %%
# Create function for train-test-split
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  Splits matching pairs of windows and labels into train and test splits.
  """
  split_size = int(len(windows) * (1-test_split)) 
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (323152, 80789, 323152, 80789)

# %%
train_windows[:5], train_labels[:5]
# Out:
# (array([[738.5075, 735.09  , 734.8025, 731.82  , 732.9325, 732.3425,
#          731.8225],
#         [735.09  , 734.8025, 731.82  , 732.9325, 732.3425, 731.8225,
#          732.1325],
#         [734.8025, 731.82  , 732.9325, 732.3425, 731.8225, 732.1325,
#          732.605 ],
#         [731.82  , 732.9325, 732.3425, 731.8225, 732.1325, 732.605 ,
#          729.415 ],
#         [732.9325, 732.3425, 731.8225, 732.1325, 732.605 , 729.415 ,
#          731.32  ]]),
#  array([[732.1325],
#         [732.605 ],
#         [729.415 ],
#         [731.32  ],
#         [733.5625]]))

# %%
# Create model callbacks
import os

# Create a function to implement a ModelCheckpoint callback with a specific filename 
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name), # create filepath to save model
                                            verbose=0,                                    # only output a limited amount of text
                                            save_best_only=True)                          # save only the best model to file

# %% [markdown]
# #### Dense model - window = 7 horizon = 1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Set random seed for reproducible results 
tf.random.set_seed(42)

# Construct the model
dense_model = tf.keras.Sequential(
[
  layers.Dense(128, activation="relu"),
  layers.Dense(HORIZON, activation="linear") # linear activation is the same as having no activation                        
], name="dense_model_1")                     # name of the model to save

# Compile the model
dense_model.compile(loss="mae",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["mae"])             

# Fit the model
dense_model.fit(x=train_windows,             # train windows of 7 timesteps of Ethereum prices
            y=train_labels,                  # horizon value of 1 (using the previous 7 timesteps to predict next day)
            epochs=100,
            verbose=1,
            batch_size=128,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=dense_model.name)]) # create ModelCheckpoint callback 
                                                                              # to save best model
# Out:
# Epoch 1/100
# 2525/2525 [==============================] - 7s 2ms/step - loss: 2.0228 - mae: 2.0228 - val_loss: 7.6264 - val_mae: 7.6264
# Epoch 2/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.3026 - mae: 1.3026 - val_loss: 7.5248 - val_mae: 7.5248
# Epoch 3/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.2204 - mae: 1.2204 - val_loss: 9.7189 - val_mae: 9.7189
# Epoch 4/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 1.1629 - mae: 1.1629 - val_loss: 6.6189 - val_mae: 6.6189
# Epoch 5/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.1626 - mae: 1.1626 - val_loss: 6.0856 - val_mae: 6.0856
# Epoch 6/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.1101 - mae: 1.1101 - val_loss: 6.9866 - val_mae: 6.9866
# Epoch 7/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.1268 - mae: 1.1268 - val_loss: 5.9226 - val_mae: 5.9226
# Epoch 8/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.0832 - mae: 1.0832 - val_loss: 10.5555 - val_mae: 10.5555
# Epoch 9/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 1.0320 - mae: 1.0320 - val_loss: 7.4443 - val_mae: 7.4443
# Epoch 10/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 1.0132 - mae: 1.0132 - val_loss: 7.8743 - val_mae: 7.8743
# Epoch 11/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9845 - mae: 0.9845 - val_loss: 6.3267 - val_mae: 6.3267
# Epoch 12/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9833 - mae: 0.9833 - val_loss: 7.2117 - val_mae: 7.2117
# Epoch 13/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9866 - mae: 0.9866 - val_loss: 7.5864 - val_mae: 7.5864
# Epoch 14/100
# 2525/2525 [==============================] - 6s 3ms/step - loss: 0.9582 - mae: 0.9582 - val_loss: 7.5148 - val_mae: 7.5148
# Epoch 15/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.9467 - mae: 0.9467 - val_loss: 7.7418 - val_mae: 7.7418
# Epoch 16/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9325 - mae: 0.9325 - val_loss: 12.1871 - val_mae: 12.1871
# Epoch 17/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.9404 - mae: 0.9404 - val_loss: 10.7265 - val_mae: 10.7265
# Epoch 18/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9355 - mae: 0.9355 - val_loss: 9.0471 - val_mae: 9.0471
# Epoch 19/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.9159 - mae: 0.9159 - val_loss: 6.0253 - val_mae: 6.0253
# Epoch 20/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9060 - mae: 0.9060 - val_loss: 7.5129 - val_mae: 7.5129
# Epoch 21/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.9083 - mae: 0.9083 - val_loss: 7.8569 - val_mae: 7.8569
# Epoch 22/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9132 - mae: 0.9132 - val_loss: 5.8968 - val_mae: 5.8968
# Epoch 23/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8874 - mae: 0.8874 - val_loss: 6.6292 - val_mae: 6.6292
# Epoch 24/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.9100 - mae: 0.9100 - val_loss: 6.8471 - val_mae: 6.8471
# Epoch 25/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8842 - mae: 0.8842 - val_loss: 5.6130 - val_mae: 5.6130
# Epoch 26/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8957 - mae: 0.8957 - val_loss: 6.6135 - val_mae: 6.6135
# Epoch 27/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8930 - mae: 0.8930 - val_loss: 5.7536 - val_mae: 5.7536
# Epoch 28/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8751 - mae: 0.8751 - val_loss: 5.7149 - val_mae: 5.7149
# Epoch 29/100
# 2525/2525 [==============================] - 7s 3ms/step - loss: 0.8767 - mae: 0.8767 - val_loss: 5.9069 - val_mae: 5.9069
# Epoch 30/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8745 - mae: 0.8745 - val_loss: 5.6146 - val_mae: 5.6146
# Epoch 31/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8820 - mae: 0.8820 - val_loss: 7.0061 - val_mae: 7.0061
# Epoch 32/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8662 - mae: 0.8662 - val_loss: 5.6804 - val_mae: 5.6804
# Epoch 33/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8761 - mae: 0.8761 - val_loss: 6.1565 - val_mae: 6.1565
# Epoch 34/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8757 - mae: 0.8757 - val_loss: 5.6076 - val_mae: 5.6076
# Epoch 35/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8597 - mae: 0.8597 - val_loss: 8.3288 - val_mae: 8.3288
# Epoch 36/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8830 - mae: 0.8830 - val_loss: 6.8530 - val_mae: 6.8530
# Epoch 37/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8576 - mae: 0.8576 - val_loss: 5.5335 - val_mae: 5.5335
# Epoch 38/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8543 - mae: 0.8543 - val_loss: 11.2955 - val_mae: 11.2955
# Epoch 39/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8562 - mae: 0.8562 - val_loss: 6.6425 - val_mae: 6.6425
# Epoch 40/100
# 2525/2525 [==============================] - 6s 3ms/step - loss: 0.8570 - mae: 0.8570 - val_loss: 5.9406 - val_mae: 5.9406
# Epoch 41/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8490 - mae: 0.8490 - val_loss: 6.7607 - val_mae: 6.7607
# Epoch 42/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8561 - mae: 0.8561 - val_loss: 5.4867 - val_mae: 5.4867
# Epoch 43/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8569 - mae: 0.8569 - val_loss: 6.2379 - val_mae: 6.2379
# Epoch 44/100
# 2525/2525 [==============================] - 6s 3ms/step - loss: 0.8525 - mae: 0.8525 - val_loss: 5.6538 - val_mae: 5.6538
# Epoch 45/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8534 - mae: 0.8534 - val_loss: 6.7533 - val_mae: 6.7533
# Epoch 46/100
# 2525/2525 [==============================] - 7s 3ms/step - loss: 0.8558 - mae: 0.8558 - val_loss: 5.4948 - val_mae: 5.4948
# Epoch 47/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8507 - mae: 0.8507 - val_loss: 5.4482 - val_mae: 5.4482
# Epoch 48/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8441 - mae: 0.8441 - val_loss: 5.7547 - val_mae: 5.7547
# Epoch 49/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8456 - mae: 0.8456 - val_loss: 5.4871 - val_mae: 5.4871
# Epoch 50/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8443 - mae: 0.8443 - val_loss: 5.6140 - val_mae: 5.6140
# Epoch 51/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8365 - mae: 0.8365 - val_loss: 6.1110 - val_mae: 6.1110
# Epoch 52/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8416 - mae: 0.8416 - val_loss: 5.7007 - val_mae: 5.7007
# Epoch 53/100
# 2525/2525 [==============================] - 6s 3ms/step - loss: 0.8480 - mae: 0.8480 - val_loss: 9.2047 - val_mae: 9.2047
# Epoch 54/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8414 - mae: 0.8414 - val_loss: 5.4442 - val_mae: 5.4442
# Epoch 55/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8407 - mae: 0.8407 - val_loss: 8.7589 - val_mae: 8.7589
# Epoch 56/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8440 - mae: 0.8440 - val_loss: 5.6817 - val_mae: 5.6817
# Epoch 57/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8270 - mae: 0.8270 - val_loss: 7.2970 - val_mae: 7.2970
# Epoch 58/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8342 - mae: 0.8342 - val_loss: 5.4692 - val_mae: 5.4692
# Epoch 59/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8328 - mae: 0.8328 - val_loss: 5.8392 - val_mae: 5.8392
# Epoch 60/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8284 - mae: 0.8284 - val_loss: 5.4152 - val_mae: 5.4152
# Epoch 61/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8399 - mae: 0.8399 - val_loss: 5.4875 - val_mae: 5.4875
# Epoch 62/100
# 2525/2525 [==============================] - 7s 3ms/step - loss: 0.8276 - mae: 0.8276 - val_loss: 7.0110 - val_mae: 7.0110
# Epoch 63/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8360 - mae: 0.8360 - val_loss: 7.2958 - val_mae: 7.2958
# Epoch 64/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8370 - mae: 0.8370 - val_loss: 7.8666 - val_mae: 7.8666
# Epoch 65/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8330 - mae: 0.8330 - val_loss: 6.1093 - val_mae: 6.1093
# Epoch 66/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8309 - mae: 0.8309 - val_loss: 5.6477 - val_mae: 5.6477
# Epoch 67/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8289 - mae: 0.8289 - val_loss: 5.7543 - val_mae: 5.7543
# Epoch 68/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8382 - mae: 0.8382 - val_loss: 7.4165 - val_mae: 7.4165
# Epoch 69/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8444 - mae: 0.8444 - val_loss: 5.6699 - val_mae: 5.6699
# Epoch 70/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8274 - mae: 0.8274 - val_loss: 5.6614 - val_mae: 5.6614
# Epoch 71/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8285 - mae: 0.8285 - val_loss: 5.8994 - val_mae: 5.8994
# Epoch 72/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8367 - mae: 0.8367 - val_loss: 7.0572 - val_mae: 7.0572
# Epoch 73/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8275 - mae: 0.8275 - val_loss: 7.0058 - val_mae: 7.0058
# Epoch 74/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8337 - mae: 0.8337 - val_loss: 5.5194 - val_mae: 5.5194
# Epoch 75/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8305 - mae: 0.8305 - val_loss: 5.9007 - val_mae: 5.9007
# Epoch 76/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8182 - mae: 0.8182 - val_loss: 7.3876 - val_mae: 7.3876
# Epoch 77/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8222 - mae: 0.8222 - val_loss: 5.9521 - val_mae: 5.9521
# Epoch 78/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8252 - mae: 0.8252 - val_loss: 5.8064 - val_mae: 5.8064
# Epoch 79/100
# 2525/2525 [==============================] - 7s 3ms/step - loss: 0.8291 - mae: 0.8291 - val_loss: 5.3884 - val_mae: 5.3884
# Epoch 80/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8175 - mae: 0.8175 - val_loss: 11.0334 - val_mae: 11.0334
# Epoch 81/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8250 - mae: 0.8250 - val_loss: 9.1348 - val_mae: 9.1348
# Epoch 82/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8234 - mae: 0.8234 - val_loss: 5.4283 - val_mae: 5.4283
# Epoch 83/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8236 - mae: 0.8236 - val_loss: 5.3822 - val_mae: 5.3822
# Epoch 84/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8155 - mae: 0.8155 - val_loss: 5.7042 - val_mae: 5.7042
# Epoch 85/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8166 - mae: 0.8166 - val_loss: 6.4029 - val_mae: 6.4029
# Epoch 86/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8221 - mae: 0.8221 - val_loss: 5.3744 - val_mae: 5.3744
# Epoch 87/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8251 - mae: 0.8251 - val_loss: 6.7075 - val_mae: 6.7075
# Epoch 88/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8102 - mae: 0.8102 - val_loss: 6.3430 - val_mae: 6.3430
# Epoch 89/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8245 - mae: 0.8245 - val_loss: 5.3737 - val_mae: 5.3737
# Epoch 90/100
# 2525/2525 [==============================] - 7s 3ms/step - loss: 0.8191 - mae: 0.8191 - val_loss: 5.3767 - val_mae: 5.3767
# Epoch 91/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8085 - mae: 0.8085 - val_loss: 6.2664 - val_mae: 6.2664
# Epoch 92/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8240 - mae: 0.8240 - val_loss: 5.6434 - val_mae: 5.6434
# Epoch 93/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8029 - mae: 0.8029 - val_loss: 5.5946 - val_mae: 5.5946
# Epoch 94/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8123 - mae: 0.8123 - val_loss: 6.8236 - val_mae: 6.8236
# Epoch 95/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8145 - mae: 0.8145 - val_loss: 5.6075 - val_mae: 5.6075
# Epoch 96/100
# 2525/2525 [==============================] - 5s 2ms/step - loss: 0.8145 - mae: 0.8145 - val_loss: 5.5392 - val_mae: 5.5392
# Epoch 97/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8158 - mae: 0.8158 - val_loss: 5.6928 - val_mae: 5.6928
# Epoch 98/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.7969 - mae: 0.7969 - val_loss: 6.8755 - val_mae: 6.8755
# Epoch 99/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8158 - mae: 0.8158 - val_loss: 6.1433 - val_mae: 6.1433
# Epoch 100/100
# 2525/2525 [==============================] - 6s 2ms/step - loss: 0.8152 - mae: 0.8152 - val_loss: 5.4806 - val_mae: 5.4806

# %%
# Evaluate model on the test data
dense_model.evaluate(test_windows, test_labels)
# Out:
# 2525/2525 [==============================] - 4s 1ms/step - loss: 5.4806 - mae: 5.4806
# [5.480630397796631, 5.480630397796631]

# %%
# Load in saved best performing model and evaluate on the test data
dense_model = tf.keras.models.load_model("model_experiments/dense_model_1")
dense_model.evaluate(test_windows, test_labels)
# Out:
# 2525/2525 [==============================] - 4s 1ms/step - loss: 5.3737 - mae: 5.3737
# [5.37371826171875, 5.37371826171875]

# %%
# Function for forecasting on the test dataset
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
       model: trained model 
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  # return 1D array of predictions  
  return tf.squeeze(forecast)

# %%
# Make predictions using dense_model on the test dataset and view the results
dense_model_preds = make_preds(dense_model, test_windows)
len(dense_model_preds), dense_model_preds[:10]
# Out:
# (80789,
#  <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([1225.3612, 1231.0071, 1229.0295, 1228.6338, 1227.2433, 1227.8109,
#         1228.2229, 1221.4147, 1225.6765, 1227.5248], dtype=float32)>)

# %%
# Function to evaluate prediction
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  
  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy()}

# %%
# Evaluate prediction
dense_model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                     y_pred=dense_model_preds)
dense_model_results
# Out:
# {'mae': 5.373713, 'mse': 78.89699, 'rmse': 8.882398, 'mape': 0.22432236}
